# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from scipy.special import softmax
from sklearn.preprocessing import MinMaxScaler, minmax_scale

# %% [markdown]
# ## VALID DATA

# %%
trainDataFull = pd.read_csv("trainData.csv")
trainDataFull.head(3)
# Out:
#     v1  v10  v100  v101  v102  v103  v11  v12  v13  v14  ...  v91  v92  v93  \
# 0  1.4  0.0   0.2   1.0   4.2   0.4  0.0  0.0  0.0  1.2  ...  0.6  0.2  0.0
# 1  0.0  0.0   0.0   2.8   0.0   0.8  0.0  0.2  1.2  1.4  ...  0.0  0.0  1.2
# 2  0.0  0.0   0.0   0.4   0.0   0.6  0.8  0.0  0.0  0.2  ...  0.0  0.0  0.0
#
#    v94  v95  v96  v97  v98  v99  target
# 0  3.2  1.0  0.2  0.0  1.6  0.4       9
# 1  0.0  1.2  0.2  0.2  2.6  2.2       6
# 2  0.0  0.8  0.2  0.8  1.4  0.0       3
#
# [3 rows x 104 columns]

# %%
trainData = trainDataFull.loc[:,'v1':'v99']
trainData.head(3)
# Out:
#     v1  v10  v100  v101  v102  v103  v11  v12  v13  v14  ...  v90  v91  v92  \
# 0  1.4  0.0   0.2   1.0   4.2   0.4  0.0  0.0  0.0  1.2  ...  0.2  0.6  0.2
# 1  0.0  0.0   0.0   2.8   0.0   0.8  0.0  0.2  1.2  1.4  ...  0.0  0.0  0.0
# 2  0.0  0.0   0.0   0.4   0.0   0.6  0.8  0.0  0.0  0.2  ...  0.0  0.0  0.0
#
#    v93  v94  v95  v96  v97  v98  v99
# 0  0.0  3.2  1.0  0.2  0.0  1.6  0.4
# 1  1.2  0.0  1.2  0.2  0.2  2.6  2.2
# 2  0.0  0.0  0.8  0.2  0.8  1.4  0.0
#
# [3 rows x 103 columns]

# %%
trainLabels = trainDataFull.loc[:,'target']
trainLabels.unique()
# Out:
# array([9, 6, 3, 4, 2, 8, 7, 1, 5])

# %%
# encode string class values as integers
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(trainLabels)
label_encoded_y = label_encoder.transform(trainLabels)
label_encoded_y
# Out:
# array([8, 5, 2, ..., 7, 4, 2])

# %%
X_train, X_test, y_train, y_test = train_test_split(trainData.values, 
                                                    label_encoded_y, 
                                                    test_size = 0.05, 
                                                    random_state = 33,
                                                    shuffle = True,
                                                    stratify = label_encoded_y)

# %% [markdown]
# ## FUSION

# %%
valid_RFC = pd.read_csv("./results/valid-submission-xgboost-1-optimal.csv")
valid_RFC.head()
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  0.000293  0.000461  0.000714  0.000118  0.000025  0.001526  0.000245
# 1  0.000115  0.000020  0.000020  0.000010  0.000005  0.000596  0.000219
# 2  0.003406  0.000085  0.000136  0.000131  0.000117  0.001847  0.007751
# 3  0.002974  0.000331  0.000283  0.000517  0.000025  0.002343  0.000145
# 4  0.001298  0.000996  0.000835  0.006854  0.000119  0.968363  0.003845
#
#          c8        c9
# 0  0.996494  0.000124
# 1  0.998951  0.000064
# 2  0.986110  0.000418
# 3  0.000472  0.992909
# 4  0.015608  0.002083

# %%
valid_xgboost = pd.read_csv("./results/valid-submission-xgboost-2-optimal.csv")
valid_xgboost.head()
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  0.000101  0.000115  0.000221  0.000042  0.000017  0.000661  0.000033
# 1  0.000051  0.000007  0.000009  0.000002  0.000012  0.000577  0.000098
# 2  0.004228  0.000037  0.000045  0.000079  0.000183  0.002042  0.006516
# 3  0.001666  0.000080  0.000136  0.000307  0.000060  0.002291  0.000077
# 4  0.001465  0.000501  0.000218  0.002832  0.000322  0.967463  0.003802
#
#          c8        c9
# 0  0.998791  0.000018
# 1  0.999205  0.000038
# 2  0.986677  0.000193
# Weight: 0.69 Accuracy: 83.58%
# Weight: 0.70 Accuracy: 83.58%
# Weight: 0.71 Accuracy: 83.55%
# Weight: 0.72 Accuracy: 83.55%
# Weight: 0.73 Accuracy: 83.55%
# Weight: 0.74 Accuracy: 83.55%
# Weight: 0.75 Accuracy: 83.55%
# Weight: 0.76 Accuracy: 83.58%
# Weight: 0.77 Accuracy: 83.55%
# Weight: 0.78 Accuracy: 83.52%
# Weight: 0.79 Accuracy: 83.52%
# Weight: 0.80 Accuracy: 83.48%
# Weight: 0.81 Accuracy: 83.48%
# Weight: 0.82 Accuracy: 83.45%
# Weight: 0.83 Accuracy: 83.48%
# Weight: 0.84 Accuracy: 83.52%
# Weight: 0.85 Accuracy: 83.58%
# Weight: 0.86 Accuracy: 83.68%
# Weight: 0.87 Accuracy: 83.61%
# Weight: 0.88 Accuracy: 83.61%
# Weight: 0.89 Accuracy: 83.58%
# Weight: 0.90 Accuracy: 83.48%
# Weight: 0.91 Accuracy: 83.52%
# Weight: 0.92 Accuracy: 83.52%
# Weight: 0.93 Accuracy: 83.52%
# Weight: 0.94 Accuracy: 83.55%
# Weight: 0.95 Accuracy: 83.55%
# Weight: 0.96 Accuracy: 83.65%
# Weight: 0.97 Accuracy: 83.65%
# Weight: 0.98 Accuracy: 83.65%
# Weight: 0.99 Accuracy: 83.65%
# Weight: 1.00 Accuracy: 83.61%
# Weight: 1.01 Accuracy: 83.61%
# Weight: 1.02 Accuracy: 83.61%
# Weight: 1.03 Accuracy: 83.58%
# Weight: 1.04 Accuracy: 83.61%
# Weight: 1.05 Accuracy: 83.65%
# Weight: 1.06 Accuracy: 83.65%
# Weight: 1.07 Accuracy: 83.65%
# Weight: 1.08 Accuracy: 83.58%
# Weight: 1.09 Accuracy: 83.61%

# %%
fusion_standart = (0.29*valid_RFC.values + 0.71*valid_xgboost.values)
fusion_standart_score = pd.DataFrame(fusion_standart, columns=['c1','c2','c3','c4','c5','c6','c7','c8','c9'])
fusion_standart_score
# Out:
#             c1        c2        c3        c4        c5        c6        c7  \
# 0     0.000157  0.000215  0.000364  0.000064  0.000019  0.000912  0.000095
# 1     0.000070  0.000011  0.000012  0.000004  0.000010  0.000583  0.000134
# 2     0.003990  0.000051  0.000071  0.000094  0.000164  0.001985  0.006874
# 3     0.002046  0.000153  0.000178  0.000368  0.000050  0.002306  0.000097
# 4     0.001416  0.000644  0.000397  0.003998  0.000263  0.967724  0.003815
# ...        ...       ...       ...       ...       ...       ...       ...
# 3089  0.001220  0.699533  0.121080  0.046234  0.000441  0.002600  0.126199
# 3090  0.000210  0.082008  0.051539  0.860543  0.000701  0.000532  0.001301
# 3091  0.001883  0.000013  0.000014  0.000166  0.000032  0.996389  0.000699
# 3092  0.000850  0.088157  0.885764  0.021641  0.000605  0.000867  0.000554
# 3093  0.001746  0.000200  0.000142  0.000034  0.000080  0.001570  0.002944
#
#             c8        c9
# 0     0.998125  0.000049
# 1     0.999131  0.000046
# 2     0.986512  0.000258
# 3     0.000445  0.994358
# 4     0.019964  0.001778
# ...        ...       ...
# 3089  0.002391  0.000301
# 3090  0.000455  0.002710
# 3091  0.000741  0.000063
# 3092  0.000394  0.001169
# 3093  0.992969  0.000314
#
# [3094 rows x 9 columns]

# %%
fusion_standart_score.to_csv('./results/valid-fusion-optimal.csv', index = False)

# %% [markdown]
# ### Normalized Fusion

# %%
def tanh_normalize(x):
    
    y = x.transpose()
    m = np.mean(y, axis=0)
    std = np.std(y, axis=0)
    normalized = 0.5 * (np.tanh(0.01 * ((y - m / std)) + 1))

    return normalized.transpose()

# %%
RFC_normalized = tanh_normalize(valid_RFC.values)
xgboost_normalized = tanh_normalize(valid_xgboost.values)

# %%
# Exahustive Search
for i in np.arange(0, 1.1, 0.1):
    fusionX = (i*RFC_normalized + (1-i)*xgboost_normalized)
    predictions = np.argmax(fusionX,1)
    accuracy = accuracy_score(y_test, predictions)
    print("Weight: %.2f Accuracy: %.2f%%" % (i ,accuracy * 100.0))

# %%
fusion_normalized = (0.5*RFC_normalized + 0.5*xgboost_normalized)
fusion_normalized_score = pd.DataFrame(fusion_normalized, columns=['c1','c2','c3','c4','c5','c6','c7','c8','c9'])
fusion_normalized_score.head()

# %%
scaler = MinMaxScaler()
scaler.fit(fusion_normalized)
MinMax_reconstruct = scaler.transform(fusion_normalized)

# %%
MinMax_reconstruct = softmax(minmax_scale(fusion_normalized,axis=1),axis=1)
fusion_reconstruct_score = pd.DataFrame(MinMax_reconstruct, columns=['c1','c2','c3','c4','c5','c6','c7','c8','c9'])
fusion_reconstruct_score.head(100)

# %%
fusion_reconstruct_score.to_csv('./results/valid-fusion-normalized.csv', index = False)

# %% [markdown]
# ## TEST DATA

# %%
test_RFC = pd.read_csv("./results/test-submission-model-nn.csv")
test_RFC.head()
# Out:
#              c1            c2            c3            c4            c5  \
# 0  1.000881e-04  2.973343e-01  3.732213e-01  3.219612e-01  8.985221e-08
# 1  2.459792e-04  3.173853e-04  1.044408e-05  3.075071e-06  2.177567e-07
# 2  3.064437e-07  4.021253e-08  1.255420e-08  1.021791e-08  2.078018e-08
# 3  1.762037e-07  7.405864e-01  2.571583e-01  2.252082e-03  4.259134e-08
# 4  3.927379e-01  2.821333e-06  3.308079e-07  1.022413e-07  1.701025e-07
#
#              c6        c7            c8            c9
# 0  6.293251e-05  0.007315  5.150354e-06  4.378657e-07
# 1  7.232735e-01  0.000262  2.753139e-01  5.738090e-04
# 2  9.999857e-01  0.000003  1.154281e-05  1.248012e-07
# 3  6.713095e-08  0.000002  2.728781e-07  9.686786e-07
# 4  1.261078e-03  0.000283  2.064538e-02  5.850698e-01

# %%
test_xgboost = pd.read_csv("./results/submission-model-2-optimal.csv")
test_xgboost.head()
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  0.000446  0.078695  0.108564  0.808224  0.000431  0.000071  0.003252
# 1  0.004290  0.025319  0.001983  0.001405  0.001005  0.137486  0.003490
# 2  0.000058  0.000014  0.000041  0.000022  0.000022  0.999038  0.000063
# 3  0.000563  0.763614  0.221859  0.008738  0.000502  0.000344  0.000450
# 4  0.042744  0.000797  0.000350  0.000127  0.001041  0.002581  0.000740
#
#          c8        c9
# 0  0.000257  0.000060
# 1  0.823050  0.001972
# 2  0.000710  0.000031
# 3  0.001220  0.002711
# 4  0.029084  0.922536

# %%
test_fusion_standart = (0.29*test_RFC.values + 0.71*test_xgboost.values)
test_fusion_standart_score = pd.DataFrame(test_fusion_standart, columns=['c1','c2','c3','c4','c5','c6','c7','c8','c9'])
test_fusion_standart_score.head()
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  0.000346  0.142100  0.185315  0.667208  0.000306  0.000069  0.004430
# 1  0.003117  0.018069  0.001411  0.000998  0.000714  0.307364  0.002554
# 2  0.000041  0.000010  0.000029  0.000016  0.000016  0.999313  0.000046
# 3  0.000400  0.756936  0.232096  0.006857  0.000357  0.000244  0.000320
# 4  0.144242  0.000566  0.000249  0.000090  0.000739  0.002198  0.000608
#
#          c8        c9
# 0  0.000184  0.000043
# 1  0.664207  0.001566
# 2  0.000507  0.000022
# 3  0.000866  0.001925
# 4  0.026637  0.824671

# %%
test_fusion_standart_score.to_csv('./results/test-fusion-nn.csv', index = False)
